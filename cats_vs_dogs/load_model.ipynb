# %%
import tensorflow

# %%
new_model = tensorflow.keras.models.load_model('mymodel.h5')

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

#path of test img
test_dir = 'data/test'
test_fname = os.listdir(test_dir)

for f in test_fname:
 
  # predicting images
    path = os.path.join(test_dir, f)
    img=image.load_img(path, target_size=(150, 150))
    
    x=image.img_to_array(img)/255.
    x=np.expand_dims(x, axis=0)
  
    classes = new_model.predict(x, batch_size=10)
    plt.figure()
    if classes[0]<0.5:
    
        I = mpimg.imread(path)
        plt.imshow(I)
        plt.title(f + " is a cat")
    
    else:
        I = mpimg.imread(path)
        plt.imshow(I)
        plt.title(f + " is a dog")
